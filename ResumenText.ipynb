# %%
import re
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

def summarize(text, num_sentences):
    # Tokenize the text into sentences
    sentences = sent_tokenize(text)
    
    # If the number of sentences requested is greater than the total number of sentences in the text, return the original text
    if num_sentences >= len(sentences):
        return text
    
    # Create a list of stopwords
    stop_words = set(stopwords.words("english"))
    
    # Create a dictionary to store the frequency of each word in the text
    word_freq = {}
    
    # Create a Porter stemmer object
    stemmer = PorterStemmer()
    
    # Loop through each sentence in the text
    for sentence in sentences:
        # Tokenize the sentence into words
        words = word_tokenize(sentence)
        
        # Loop through each word in the sentence
        for word in words:
            # Remove any special characters from the word
            word = re.sub(r"[^a-zA-Z0-9]", "", word)
            
            # Convert the word to lowercase
            word = word.lower()
            
            # If the word is not a stopword and is not an empty string, stem it and add it to the dictionary
            if word != "" and word not in stop_words:
                word = stemmer.stem(word)
                if word in word_freq:
                    word_freq[word] += 1
                else:
                    word_freq[word] = 1
    
    # Create a list of tuples, where each tuple is a (word, frequency) pair
    freq_list = [(word, freq) for word, freq in word_freq.items()]
    
    # Sort the list of tuples by frequency in descending order
    freq_list.sort(key=lambda x: x[1], reverse=True)
    
    # Create an empty list to store the most frequent words
    most_freq = []
    
    # Get the `num_sentences` most frequent words
    for i in range(num_sentences):
        most_freq.append(freq_list[i][0])
    
    # Create a new list to store the summarized sentences
    summary = []
    
    # Loop through each sentence in the original text
    for sentence in sentences:
        # Tokenize the sentence into words
        words = word_tokenize(sentence)
        
        # Create a new list to store the stemmed words in the sentence
        stemmed_words = []
        
        # Loop through each word in the sentence
        for word in words:
            # Remove any special characters from the word
            word = re.sub(r"[^a-zA-Z0-9]", "", word)
            
            # Convert the word to lowercase
            word = word.lower()

# %%
# Import the required modules
import re
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

def summarize(text, num_sentences):
    # Tokenize the text into sentences
    sentences = sent_tokenize(text)
    
    # If the number of sentences requested is greater than the total number of sentences in the text, return the original text
    if num_sentences >= len(sentences):
        return text
    
    # Create a list of stopwords
    stop_words = set(stopwords.words("english"))
    
    # Create a dictionary to store the frequency of each word in the text
    word_freq = {}
    
    # Create a Porter stemmer object
    stemmer = PorterStemmer()
    
    # Loop through each sentence in the text
    for sentence in sentences:
        # Tokenize the sentence into words
        words = word_tokenize(sentence)
        
        # Loop through each word in the sentence
        for word in words:
            # Remove any special characters from the word
            word = re.sub(r"[^a-zA-Z0-9]", "", word)
            
            # Convert the word to lowercase
            word = word.lower()
            
            # If the word is not a stopword and is not an empty string, stem it and add it to the dictionary
            if word != "" and word not in stop_words:
                word = stemmer.stem(word)
                if word in word_freq:
                    word_freq[word] += 1
                else:
                    word_freq[word] = 1
    
    # Create a list of tuples, where each tuple is a (word, frequency) pair
    freq_list = [(word, freq) for word, freq in word_freq.items()]
    
    # Sort the list of tuples by frequency in descending order
    freq_list.sort(key=lambda x: x[1], reverse=True)
    
    # Create an empty list to store the most frequent words
    most_freq = []
    
    # Get the `num_sentences` most frequent words
    for i in range(num_sentences):
        most_freq.append(freq_list[i][0])
    
    # Create a new list to store the summarized sentences
    summary = []
    
    # Loop through each sentence in the original text
    for sentence in sentences:
        # Tokenize the sentence into words
        words = word_tokenize(sentence)
        
        # Create a new list to store the stemmed words in the sentence
        stemmed_words = []
        
        # Loop through each word in the sentence
        for word in words:
            # Remove any special characters from the word
            word = re.sub(r"[^a-zA-Z0-9]", "", word)

            # Convert the word to lowercase
            word = word.lower()
            
            # If the word is not an empty string and is not a stopword, stem it and
            if word != "" and word not in stop_words:
                            word = stemmer.stem(word)
                            if word in word_freq:
                                word_freq[word] += 1
                            else:
                                word_freq[word] = 1
    
    # Create a list of tuples, where each tuple is a (word, frequency) pair
    freq_list = [(word, freq) for word, freq in word_freq.items()]
    
    # Sort the list of tuples by frequency in descending order
    freq_list.sort(key=lambda x: x[1], reverse=True)
    
    # Create an empty list to store the most frequent words
    most_freq = []
    
    # Get the `num_sentences` most frequent words
    for i in range(num_sentences):
        most_freq.append(freq_list[i][0])
    
    # Create a new list to store the summarized sentences
    summary = []
    
    # Loop through each sentence in the original text
    for sentence in sentences:
        # Tokenize the sentence into words
        words = word_tokenize(sentence)
        
        # Create a new list to store the stemmed words in the sentence
        stemmed_words = []
        
        # Loop

# %%
from gensim.summarization import summarize
import io

def summarize_text(text, ratio=0.1):
    return summarize(text, ratio=ratio)


with io.open('test.txt', 'r', encoding='utf-8') as txt_file:
            text = txt_file.read()
summary = summarize_text(text, ratio=0.1)

# %%
with open("summary.txt", "w", encoding="utf-8") as file:
   # Write the string to the file
   file.write(summary)
